# %% [markdown]
# <a href="https://colab.research.google.com/github/melkatewabe10/Machine-learning_LST-Estimation-/blob/main/NDVI_EVI_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Author**: **Tewabe** **Melkamu**
#
# Date: 3/13/2025
#
# NDVI_EVI_Data Collection

# %%
import ee
import folium
import matplotlib.pyplot as plt
import geemap
import math
# Authenticate to Earth Engine. This will open a browser window.
ee.Authenticate()

# Initialize the Earth Engine API.
ee.Initialize(project='ee-mftewabe')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Data spacification and visualization

# %%
# -------------------------------------------------------------------
# 1. Define the study region (Taiwan)
# -------------------------------------------------------------------
gaul = ee.FeatureCollection("FAO/GAUL/2015/level0")
taiwan = gaul.filter(ee.Filter.eq('ADM0_NAME', 'Taiwan'))

# # -------------------------------------------------------------------
# # 2. Load ESA WorldCover and create a mask
# # -------------------------------------------------------------------
# worldcover = ee.ImageCollection("ESA/WorldCover/v200").first().clip(taiwan)
# mask = worldcover.neq(50).And(worldcover.neq(80))  # Remove built-up and water

# -------------------------------------------------------------------
# 3. Define Seasons
# -------------------------------------------------------------------
seasons = {
    "Spring": ('03-01', '05-31'),
    "Summer": ('06-01', '08-31'),
    "Autumn": ('09-01', '11-30'),
    "Winter": ('12-01', '02-28')  # Winter spans two years
}

# -------------------------------------------------------------------
# 4. Loop through each year and export seasonal EVI
# -------------------------------------------------------------------
for year in range(2000, 2025):
    print(f"Processing year: {year}")

    for season, (start, end) in seasons.items():
        print(f"  Processing {season} of {year}")

        if season == "Winter":
            # Winter spans two years
            start_date = ee.Date(f"{year}-12-01")
            end_date = ee.Date(f"{year + 1}-02-28")  # Move to next year
        else:
            start_date = ee.Date(f"{year}-{start}")
            end_date = ee.Date(f"{year}-{end}")

        # Compute seasonal mean EVI
        EVI = (ee.ImageCollection("MODIS/061/MOD13A2")
                .filterDate(start_date, end_date)
                .filterBounds(taiwan)
                .select('EVI')
                .mean()
                .clip(taiwan))

        # Convert raw EVI values using the MODIS scale factor (0.0001)
        EVI_scaled = EVI.multiply(0.0001)

        # # Apply land mask
        # EVI_masked = EVI_scaled.updateMask(mask)

        # Export to Google Drive
        task = ee.batch.Export.image.toDrive(
            image=EVI_scaled,
            description=f'EVI_{year}_{season}',
            folder='EVI',  # Update this to your desired Drive folder
            fileNamePrefix=f'EVI_{year}_{season}',
            region=taiwan.geometry().bounds().getInfo()['coordinates'],
            scale=1000,  # MODIS resolution (~1 km)
            crs='EPSG:32651',
            maxPixels=1e13
        )

        task.start()
        print(f"Export task for {year} - {season} started.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing year: 2000
#   Processing Spring of 2000
# Export task for 2000 - Spring started.
#   Processing Summer of 2000
# Export task for 2000 - Summer started.
#   Processing Autumn of 2000
# Export task for 2000 - Autumn started.
#   Processing Winter of 2000
# Export task for 2000 - Winter started.
# Processing year: 2001
#   Processing Spring of 2001
# Export task for 2001 - Spring started.
#   Processing Summer of 2001
# Export task for 2001 - Summer started.
#   Processing Autumn of 2001
# Export task for 2001 - Autumn started.
#   Processing Winter of 2001
# Export task for 2001 - Winter started.
# Processing year: 2002
#   Processing Spring of 2002
# Export task for 2002 - Spring started.
#   Processing Summer of 2002
# Export task for 2002 - Summer started.
#   Processing Autumn of 2002
# Export task for 2002 - Autumn started.
#   Processing Winter of 2002
# Export task for 2002 - Winter started.
# Processing year: 2003
#   Processing Spring of 2003
# Export task for 2003 - Spring started.
#   Processing Summer of 2003
# Export task for 2003 - Summer started.
#   Processing Autumn of 2003
# Export task for 2003 - Autumn started.
#   Processing Winter of 2003
# Export task for 2003 - Winter started.
# Processing year: 2004
#   Processing Spring of 2004
# Export task for 2004 - Spring started.
#   Processing Summer of 2004
# Export task for 2004 - Summer started.
#   Processing Autumn of 2004
# Export task for 2004 - Autumn started.
#   Processing Winter of 2004
# Export task for 2004 - Winter started.
# Processing year: 2005
#   Processing Spring of 2005
# Export task for 2005 - Spring started.
#   Processing Summer of 2005
# Export task for 2005 - Summer started.
#   Processing Autumn of 2005
# Export task for 2005 - Autumn started.
#   Processing Winter of 2005
# Export task for 2005 - Winter started.
# Processing year: 2006
#   Processing Spring of 2006
# Export task for 2006 - Spring started.
#   Processing Summer of 2006
# Export task for 2006 - Summer started.
#   Processing Autumn of 2006
# Export task for 2006 - Autumn started.
#   Processing Winter of 2006
# Export task for 2006 - Winter started.
# Processing year: 2007
#   Processing Spring of 2007
# Export task for 2007 - Spring started.
#   Processing Summer of 2007
# Export task for 2007 - Summer started.
#   Processing Autumn of 2007
# Export task for 2007 - Autumn started.
#   Processing Winter of 2007
# Export task for 2007 - Winter started.
# Processing year: 2008
#   Processing Spring of 2008
# Export task for 2008 - Spring started.
#   Processing Summer of 2008
# Export task for 2008 - Summer started.
#   Processing Autumn of 2008
# Export task for 2008 - Autumn started.
#   Processing Winter of 2008
# Export task for 2008 - Winter started.
# Processing year: 2009
#   Processing Spring of 2009
# Export task for 2009 - Spring started.
#   Processing Summer of 2009
# Export task for 2009 - Summer started.
#   Processing Autumn of 2009
# Export task for 2009 - Autumn started.
#   Processing Winter of 2009
# Export task for 2009 - Winter started.
# Processing year: 2010
#   Processing Spring of 2010
# Export task for 2010 - Spring started.
#   Processing Summer of 2010
# Export task for 2010 - Summer started.
#   Processing Autumn of 2010
# Export task for 2010 - Autumn started.
#   Processing Winter of 2010
# Export task for 2010 - Winter started.
# Processing year: 2011
#   Processing Spring of 2011
# Export task for 2011 - Spring started.
#   Processing Summer of 2011
# Export task for 2011 - Summer started.
#   Processing Autumn of 2011
# Export task for 2011 - Autumn started.
#   Processing Winter of 2011
# Export task for 2011 - Winter started.
# Processing year: 2012
#   Processing Spring of 2012
# Export task for 2012 - Spring started.
#   Processing Summer of 2012
# Export task for 2012 - Summer started.
#   Processing Autumn of 2012
# Export task for 2012 - Autumn started.
#   Processing Winter of 2012
# Export task for 2012 - Winter started.
# Processing year: 2013
#   Processing Spring of 2013
# Export task for 2013 - Spring started.
#   Processing Summer of 2013
# Export task for 2013 - Summer started.
#   Processing Autumn of 2013
# Export task for 2013 - Autumn started.
#   Processing Winter of 2013
# Export task for 2013 - Winter started.
# Processing year: 2014
#   Processing Spring of 2014
# Export task for 2014 - Spring started.
#   Processing Summer of 2014
# Export task for 2014 - Summer started.
#   Processing Autumn of 2014
# Export task for 2014 - Autumn started.
#   Processing Winter of 2014
# Export task for 2014 - Winter started.
# Processing year: 2015
#   Processing Spring of 2015
# Export task for 2015 - Spring started.
#   Processing Summer of 2015
# Export task for 2015 - Summer started.
#   Processing Autumn of 2015
# Export task for 2015 - Autumn started.
#   Processing Winter of 2015
# Export task for 2015 - Winter started.
# Processing year: 2016
#   Processing Spring of 2016
# Export task for 2016 - Spring started.
#   Processing Summer of 2016
# Export task for 2016 - Summer started.
#   Processing Autumn of 2016
# Export task for 2016 - Autumn started.
#   Processing Winter of 2016
# Export task for 2016 - Winter started.
# Processing year: 2017
#   Processing Spring of 2017
# Export task for 2017 - Spring started.
#   Processing Summer of 2017
# Export task for 2017 - Summer started.
#   Processing Autumn of 2017
# Export task for 2017 - Autumn started.
#   Processing Winter of 2017
# Export task for 2017 - Winter started.
# Processing year: 2018
#   Processing Spring of 2018
# Export task for 2018 - Spring started.
#   Processing Summer of 2018
# Export task for 2018 - Summer started.
#   Processing Autumn of 2018
# Export task for 2018 - Autumn started.
#   Processing Winter of 2018
# Export task for 2018 - Winter started.
# Processing year: 2019
#   Processing Spring of 2019
# Export task for 2019 - Spring started.
#   Processing Summer of 2019
# Export task for 2019 - Summer started.
#   Processing Autumn of 2019
# Export task for 2019 - Autumn started.
#   Processing Winter of 2019
# Export task for 2019 - Winter started.
# Processing year: 2020
#   Processing Spring of 2020
# Export task for 2020 - Spring started.
#   Processing Summer of 2020
# Export task for 2020 - Summer started.
#   Processing Autumn of 2020
# Export task for 2020 - Autumn started.
#   Processing Winter of 2020
# Export task for 2020 - Winter started.
# Processing year: 2021
#   Processing Spring of 2021
# Export task for 2021 - Spring started.
#   Processing Summer of 2021
# Export task for 2021 - Summer started.
#   Processing Autumn of 2021
# Export task for 2021 - Autumn started.
#   Processing Winter of 2021
# Export task for 2021 - Winter started.
# Processing year: 2022
#   Processing Spring of 2022
# Export task for 2022 - Spring started.
#   Processing Summer of 2022
# Export task for 2022 - Summer started.
#   Processing Autumn of 2022
# Export task for 2022 - Autumn started.
#   Processing Winter of 2022
# Export task for 2022 - Winter started.
# Processing year: 2023
#   Processing Spring of 2023
# Export task for 2023 - Spring started.
#   Processing Summer of 2023
# Export task for 2023 - Summer started.
#   Processing Autumn of 2023
# Export task for 2023 - Autumn started.
#   Processing Winter of 2023
# Export task for 2023 - Winter started.
# Processing year: 2024
#   Processing Spring of 2024
# Export task for 2024 - Spring started.
#   Processing Summer of 2024
# Export task for 2024 - Summer started.
#   Processing Autumn of 2024
# Export task for 2024 - Autumn started.
#   Processing Winter of 2024
# Export task for 2024 - Winter started.

# %%
# -------------------------------------------------------------------
# 1. Define the study region (Taiwan)
# -------------------------------------------------------------------
# Using the USDOS/LSIB_SIMPLE/2017 dataset.
# If Taiwan is not available in this dataset, consider an alternative source.
gaul = ee.FeatureCollection("FAO/GAUL/2015/level0")
taiwan = gaul.filter(ee.Filter.eq('ADM0_NAME', 'Taiwan'))

# -------------------------------------------------------------------
# 2. Load ESA WorldCover and create a mask
# -------------------------------------------------------------------
# Load the first image from ESA WorldCover and clip it to Taiwan.
worldcover = ee.ImageCollection("ESA/WorldCover/v200").first().clip(taiwan)
# Class definitions from ESA WorldCover:
# 50 = Built-up, 80 = Permanent water bodies.
# We remove both built-up and permanent water by keeping pixels that are not 50 and not 80.
mask = worldcover.neq(50).And(worldcover.neq(80))

# Create an interactive map (optional).
#Map = geemap.Map(center=[23.5, 121], zoom=7)

# -------------------------------------------------------------------
# 3. Loop through each year from 2004 to 2024 and export the yearly mean LST
# -------------------------------------------------------------------
for year in range(2000, 2025):
    print(f"Processing year: {year}")

    # Define the date range for the year.
    start_date = ee.Date(f'{year}-01-01')
    end_date = ee.Date(f'{year}-12-31')

    # Compute the mean LST image for the year using the MODIS LST (MODIS/061/MOD11A1).
    Evi = (ee.ImageCollection("MODIS/061/MOD13A2")
                .filterDate(start_date, end_date)
                .filterBounds(taiwan)
                .select('EVI')
                .mean()
                .clip(taiwan))

    # Multiply by 0.02 to convert the raw values to Kelvin.
    Evi_s = Evi.multiply(0.0001)

    # Apply the mask.
    Evi_masked = Evi_s.updateMask(mask)

    # Define and start the export task.
    task = ee.batch.Export.image.toDrive(
        image=Evi_masked,
        description=f'EVI_{year}',
        folder='Taiwan_EVI',  # Update this to your desired Drive folder.
        fileNamePrefix=f'EVI_{year}',
        region=taiwan.geometry().bounds().getInfo()['coordinates'],
        scale=1000,  # MODIS resolution is approximately 1 km.
        crs='EPSG:32651',
        maxPixels=1e13
    )
    task.start()
    print(f"Export task for {year} started. Please check your GEE tasks and Google Drive.")

# Optionally, display the interactive map.
#Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing year: 2000
# Export task for 2000 started. Please check your GEE tasks and Google Drive.
# Processing year: 2001
# Export task for 2001 started. Please check your GEE tasks and Google Drive.
# Processing year: 2002
# Export task for 2002 started. Please check your GEE tasks and Google Drive.
# Processing year: 2003
# Export task for 2003 started. Please check your GEE tasks and Google Drive.
# Processing year: 2004
# Export task for 2004 started. Please check your GEE tasks and Google Drive.
# Processing year: 2005
# Export task for 2005 started. Please check your GEE tasks and Google Drive.
# Processing year: 2006
# Export task for 2006 started. Please check your GEE tasks and Google Drive.
# Processing year: 2007
# Export task for 2007 started. Please check your GEE tasks and Google Drive.
# Processing year: 2008
# Export task for 2008 started. Please check your GEE tasks and Google Drive.
# Processing year: 2009
# Export task for 2009 started. Please check your GEE tasks and Google Drive.
# Processing year: 2010
# Export task for 2010 started. Please check your GEE tasks and Google Drive.
# Processing year: 2011
# Export task for 2011 started. Please check your GEE tasks and Google Drive.
# Processing year: 2012
# Export task for 2012 started. Please check your GEE tasks and Google Drive.
# Processing year: 2013
# Export task for 2013 started. Please check your GEE tasks and Google Drive.
# Processing year: 2014
# Export task for 2014 started. Please check your GEE tasks and Google Drive.
# Processing year: 2015
# Export task for 2015 started. Please check your GEE tasks and Google Drive.
# Processing year: 2016
# Export task for 2016 started. Please check your GEE tasks and Google Drive.
# Processing year: 2017
# Export task for 2017 started. Please check your GEE tasks and Google Drive.
# Processing year: 2018
# Export task for 2018 started. Please check your GEE tasks and Google Drive.
# Processing year: 2019
# Export task for 2019 started. Please check your GEE tasks and Google Drive.
# Processing year: 2020
# Export task for 2020 started. Please check your GEE tasks and Google Drive.
# Processing year: 2021
# Export task for 2021 started. Please check your GEE tasks and Google Drive.
# Processing year: 2022
# Export task for 2022 started. Please check your GEE tasks and Google Drive.
# Processing year: 2023
# Export task for 2023 started. Please check your GEE tasks and Google Drive.
# Processing year: 2024
# Export task for 2024 started. Please check your GEE tasks and Google Drive.

# %% [markdown]
# -
#
# -
#
# -
#
# -
# **ETHIOPIA_SINGLE**

# %%
# 1. Define Ethiopia's boundary using a FeatureCollection.
gaul = ee.FeatureCollection("FAO/GAUL/2015/level0")
taiwan = gaul.filter(ee.Filter.eq('ADM0_NAME', 'Taiwan'))

# 2. Load the MODIS NDVI dataset, filter by date (January 2018) and by location (Ethiopia).
dataset = ee.ImageCollection('MODIS/061/MOD13A2') \
    .filter(ee.Filter.date('2024-01-01', '2024-12-31')) \
    .filterBounds(taiwan.geometry())

# Select the NDVI band, compute the mean over the time period, and clip to Ethiopia.
ndvi = dataset.select('NDVI').mean().clip(taiwan.geometry())

# Multiply by 0.0001 to convert the raw NDVI values (MODIS NDVI scale factor).
NDVI_1km = ndvi.multiply(0.0001)

# 3. Create a mask to remove water bodies.
# Load ESA WorldCover and clip to Ethiopia.
worldcover = ee.ImageCollection("ESA/WorldCover/v200").first().clip(taiwan)

# In ESA WorldCover, class 80 represents permanent water bodies.
# Create a mask that is True (1) for pixels NOT equal to 80.
mask = worldcover.neq(50).And(worldcover.neq(80))

# Apply the water body mask to the NDVI image.
NDVI_masked = NDVI_1km.updateMask(mask)

# Visualization parameters.
# Since NDVI is now scaled between 0 and 1, we adjust the min and max accordingly.
NDVI_vis = {
    'min': -1,
    'max': 1,
    'palette': ['blue', 'white', 'green']
}

# 4. Create an interactive map centered on Ethiopia.
# Create an interactive map (optional).
Map = geemap.Map(center=[23.5, 121], zoom=7)
Map.addLayer(NDVI_masked, NDVI_vis, 'Masked NDVI')
Map.addLayer(taiwan, {}, 'Taiwan Boundary')
Map.addLayerControl()  # Add layer control to toggle layers

# Display the map (in a Jupyter Notebook, the last statement will display the map)
Map

# %% [markdown]
#  **Export**

# %%
# -------------------------------------------------------------------
# 5. Export the masked LST image to Google Drive
# -------------------------------------------------------------------
task = ee.batch.Export.image.toDrive(
    image=NDVI_masked,
    description='NDVI_DEMO',
    folder='Taiwan_NDVI',  # Update this to your desired Drive folder.
    fileNamePrefix='NDVI_DEMO',
    region=taiwan.geometry().bounds().getInfo()['coordinates'],
    scale=1000,  # MODIS resolution is ~1 km.
    crs='EPSG:32651',
    maxPixels=1e13
)
task.start()

print("Export task started. Check your GEE tasks and Google Drive for the exported image.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Export task started. Check your GEE tasks and Google Drive for the exported image.

# %% [markdown]
# **Explor** **in** **Python**

# %%
# !pip install rasterio
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.3)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 34.8 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.3

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Path to the downloaded GeoTIFF file.
filename = '/content/drive/MyDrive/EVI/EVI_2008_Winter.tif'

# Open the file with rasterio
with rasterio.open(filename) as src:
    # Read the first band (assuming the LST is stored in a single band)
    lst_data = src.read(1)
    # Get metadata information
    meta = src.meta
    print("Metadata:")
    for key, value in meta.items():
        print(f"{key}: {value}")

# Mask no-data values (if present)
ndvi_masked = np.ma.masked_where(lst_data == src.nodata, lst_data)

# Plot the LST image using matplotlib
plt.figure(figsize=(10, 8))
cmap = plt.cm.viridis  # choose a colormap
img = plt.imshow(ndvi_masked, cmap=cmap)
plt.colorbar(img, label='LST (K)')
plt.title('MODIS LST (Masked) in Kelvin')
plt.xlabel('Column #')
plt.ylabel('Row #')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Metadata:
# driver: GTiff
# dtype: float64
# nodata: None
# width: 282
# height: 382
# count: 1
# crs: EPSG:32651
# transform: | 1000.00, 0.00, 118000.00|
# | 0.00,-1000.00, 2804000.00|
# | 0.00, 0.00, 1.00|

# %%
# prompt: HISTOGRAM

import matplotlib.pyplot as plt
# Plot the histogram of the NDVI data
plt.figure(figsize=(10, 6))
plt.hist(ndvi_masked.compressed(), bins=50, color='skyblue', edgecolor='black')
plt.title('Histogram of NDVI Values')
plt.xlabel('NDVI')
plt.ylabel('Frequency')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
